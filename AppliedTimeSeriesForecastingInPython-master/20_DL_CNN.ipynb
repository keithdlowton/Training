# %% [markdown]
# # Deep learning - CNN

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, RNN

import warnings
warnings.filterwarnings('ignore')
# Out:
# 2023-11-19 15:40:24.692306: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
plt.rcParams["figure.figsize"] = (9,6)

# %%
np.random.seed(42)
tf.random.set_seed(42)
tf.keras.utils.set_random_seed(42)

# %%
train_df = pd.read_csv('data/train.csv')
val_df = pd.read_csv('data/val.csv')
test_df = pd.read_csv('data/test.csv')

# %%
def format_timeseries_data(df, input_length, output_length, target_names):
    
    if target_names is not None:
        target_indices = {name: i for i, name in enumerate(target_names)}
    col_indices = {name: i for i, name in enumerate(df.columns)}
    
    total_length = input_length + output_length
    
    input_slice = slice(0, input_length)
    output_slice = slice(input_length, None)
    
    data = np.array(df, dtype=np.float32)
    ds = tf.keras.preprocessing.timeseries_dataset_from_array(
        data=data,
        targets=None,
        sequence_length=total_length,
        sequence_stride=1,
        shuffle=False,
        batch_size=32
    )
    
    def split_to_input_output(x):
            
        inputs = x[:, input_slice, :]
        outputs = x[:, output_slice, :]
        
        if target_names is not None:
            outputs = tf.stack(
                [outputs[:,:,col_indices[name]] for name in target_names],
                axis=-1
            )

        inputs.set_shape([None, input_length, None])
        outputs.set_shape([None, output_length, None])
    
        return inputs, outputs
    
    ds = ds.map(split_to_input_output)
    
    return ds

# %%
from tensorflow.keras.callbacks import LearningRateScheduler

def scheduler(epoch, lr):
    if epoch < 2:
        return lr
    else:
        return lr * tf.math.exp(-0.1)
    
lr_scheduler = LearningRateScheduler(scheduler)

def train_model(model, train_ds, val_ds, patience=5, max_epochs=50, use_scheduler=False):
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=patience, mode='min')
    
    model.compile(loss=MeanSquaredError(), optimizer=Adam(), metrics=[MeanAbsoluteError()])
    
    history = model.fit(train_ds, epochs=max_epochs, validation_data=val_ds, callbacks=[early_stopping])
    
    if use_scheduler == True:
        history = model.fit(train_ds, epochs=max_epochs, validation_data=val_ds, callbacks=[early_stopping, lr_scheduler])
    
    return history

# %%
def plot_history(history):

    fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)

    ax1.plot(history.history['loss'], label='Train')
    ax1.plot(history.history['val_loss'], label='Validation')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Loss')
    ax1.set_title('Loss')
    ax1.legend(loc='best')

    ax2.plot(history.history['mean_absolute_error'], label='Train')
    ax2.plot(history.history['val_mean_absolute_error'], label='Validation')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('MAE')
    ax2.set_title('Mean absolute error')
    ax2.legend(loc='best')

    plt.tight_layout()

# %%
def plot_predictions(model, sample_batch, model_type):
    
    inputs, outputs = sample_batch
    preds = model(inputs)
    
    if model_type == 'single_step':      

        fig, ax = plt.subplots()

        actual_scaled = outputs.numpy().flatten()
        actual = actual_scaled * (OT_max_test - OT_min_test) + OT_min_test
        
        predictions_scaled = preds.numpy().flatten()
        predictions = predictions_scaled * (OT_max_train - OT_min_train) + OT_min_train
        
        ax.plot(actual, label='Actual')
        ax.plot(predictions, label='Predicted')
        ax.set_xlabel('Time steps')
        ax.set_ylabel('Oil temperature')
        ax.set_title('Predictions on a sample batch')
        ax.legend(loc='best')
        
    elif model_type == 'multi_step':

        fig, ax = plt.subplots()
        
        actual_scaled = outputs.numpy().flatten()[:48]
        actual = actual_scaled * (OT_max_test - OT_min_test) + OT_min_test
        
        predictions_scaled = preds.numpy().flatten()[:48]
        predictions = predictions_scaled * (OT_max_train - OT_min_train) + OT_min_train

        ax.plot(actual, label='Actual')
        ax.plot(predictions, label='Predicted')
        ax.set_xlabel('Time steps')
        ax.set_ylabel('Oil temperature')
        ax.set_title('Predictions on a sample batch')
        ax.legend(loc='best')
        
    elif model_type == 'multi_output':
        
        fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1)
        
        OT_actual_scaled = outputs.numpy().flatten()[0::2]
        OT_actual = OT_actual_scaled * (OT_max_test - OT_min_test) + OT_min_test
        
        OT_predictions_scaled = preds.numpy().flatten()[0::2]
        OT_predictions = OT_predictions_scaled * (OT_max_train - OT_min_train) + OT_min_train

        MULL_actual_scaled = outputs.numpy().flatten()[1::2]
        MULL_actual = MULL_actual_scaled * (MULL_max_test - MULL_min_test) + MULL_min_test
        
        MULL_predictions_scaled = preds.numpy().flatten()[1::2]
        MULL_predictions = MULL_predictions_scaled * (MULL_max_train - MULL_min_train) + MULL_min_train
        
        ax1.plot(OT_actual, label='Actual')
        ax1.plot(OT_predictions, label='Predicted')
        ax1.set_xlabel('Time')
        ax1.set_ylabel('Oil temperature')
        ax1.legend(loc='best')
        ax1.set_title('Predictions on a sample batch')
        
        ax2.plot(MULL_actual, label='Actual')
        ax2.plot(MULL_predictions, label='Predicted')
        ax2.set_xlabel('Time')
        ax2.set_ylabel('MULL')
        ax2.legend(loc='best')
        
    plt.tight_layout()

# %%
def plot_evaluation(model_list, mae):
    
    fig, ax = plt.subplots()
    
    ax.bar(model_list, mae, width=0.3)
    ax.set_ylabel('MAE')
    ax.set_xlabel('Models')
    ax.set_ylim(0, max(mae)+0.15)
    for index, value in enumerate(mae):
        ax.text(x=index, y=value+0.005, s=str(round(value, 3)), ha='center')
    
    plt.tight_layout()

# %%
MULL_max_train = 7.568999767303468
MULL_min_train = -5.934000015258789
MULL_max_test = 4.690999984741211
MULL_min_test = -3.3399999141693115

OT_max_train = 46.00699996948242
OT_min_train = -4.079999923706056
OT_max_test = 17.165000915527347
OT_min_test = 3.025000095367432

# %% [markdown]
# ## Single-step model

# %%
KERNEL_LENGTH = 6
OUTPUT_LENGTH = 1
INPUT_LENGTH = OUTPUT_LENGTH + KERNEL_LENGTH - 1

train_ds_ss = format_timeseries_data(train_df, INPUT_LENGTH, OUTPUT_LENGTH, ['OT'])
val_ds_ss = format_timeseries_data(val_df, INPUT_LENGTH, OUTPUT_LENGTH, ['OT'])
test_ds_ss = format_timeseries_data(test_df, INPUT_LENGTH, OUTPUT_LENGTH, ['OT'])

ss_sample_batch = next(iter(test_ds_ss))
# Out:
# 2023-11-19 15:40:33.506082: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
ss_cnn = Sequential([
    Conv1D(filters=32, kernel_size=(KERNEL_LENGTH,), activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)
])

ss_cnn_history = train_model(ss_cnn, train_ds_ss, val_ds_ss, use_scheduler=True)
# Out:
# Epoch 1/50
# 381/381 [==============================] - 3s 4ms/step - loss: 0.0119 - mean_absolute_error: 0.0683 - val_loss: 0.0057 - val_mean_absolute_error: 0.0609
# Epoch 2/50
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0046 - mean_absolute_error: 0.0515 - val_loss: 0.0098 - val_mean_absolute_error: 0.0741
# Epoch 3/50
# 381/381 [==============================] - 2s 4ms/step - loss: 0.0042 - mean_absolute_error: 0.0491 - val_loss: 0.0066 - val_mean_absolute_error: 0.0640
# Epoch 4/50
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0038 - mean_absolute_error: 0.0462 - val_loss: 0.0148 - val_mean_absolute_error: 0.0917
# Epoch 5/50
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0034 - mean_absolute_error: 0.0426 - val_loss: 0.0145 - val_mean_absolute_error: 0.0857
# Epoch 6/50
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0029 - mean_absolute_error: 0.0392 - val_loss: 0.0164 - val_mean_absolute_error: 0.0944
# Epoch 1/50
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0024 - mean_absolute_error: 0.0355 - val_loss: 0.0223 - val_mean_absolute_error: 0.1163 - lr: 0.0010
# Epoch 2/50
# 381/381 [==============================] - 2s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0321 - val_loss: 0.0408 - val_mean_absolute_error: 0.1657 - lr: 0.0010
# Epoch 3/50
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0017 - mean_absolute_error: 0.0299 - val_loss: 0.0306 - val_mean_absolute_error: 0.1366 - lr: 9.0484e-04
# Epoch 4/50
# 381/381 [==============================] - 2s 4ms/step - loss: 0.0016 - mean_absolute_error: 0.0284 - val_loss: 0.0142 - val_mean_absolute_error: 0.0892 - lr: 8.1873e-04
# Epoch 5/50
# 381/381 [==============================] - 2s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0267 - val_loss: 0.0124 - val_mean_absolute_error: 0.0818 - lr: 7.4082e-04
# Epoch 6/50
# 381/381 [==============================] - 2s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0256 - val_loss: 0.0054 - val_mean_absolute_error: 0.0540 - lr: 6.7032e-04
# Epoch 7/50
# 381/381 [==============================] - 2s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0246 - val_loss: 0.0038 - val_mean_absolute_error: 0.0464 - lr: 6.0653e-04
# Epoch 8/50
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0243 - val_loss: 0.0017 - val_mean_absolute_error: 0.0325 - lr: 5.4881e-04
# Epoch 9/50
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0010 - mean_absolute_error: 0.0236 - val_loss: 0.0015 - val_mean_absolute_error: 0.0296 - lr: 4.9659e-04
# Epoch 10/50
# 381/381 [==============================] - 1s 3ms/step - loss: 9.9023e-04 - mean_absolute_error: 0.0233 - val_loss: 0.0011 - val_mean_absolute_error: 0.0253 - lr: 4.4933e-04
# Epoch 11/50
# 381/381 [==============================] - 1s 3ms/step - loss: 9.7386e-04 - mean_absolute_error: 0.0230 - val_loss: 0.0010 - val_mean_absolute_error: 0.0244 - lr: 4.0657e-04
# Epoch 12/50
# 381/381 [==============================] - 1s 4ms/step - loss: 9.7553e-04 - mean_absolute_error: 0.0230 - val_loss: 9.3768e-04 - val_mean_absolute_error: 0.0232 - lr: 3.6788e-04
# Epoch 13/50
# 381/381 [==============================] - 2s 4ms/step - loss: 9.8428e-04 - mean_absolute_error: 0.0230 - val_loss: 9.2148e-04 - val_mean_absolute_error: 0.0231 - lr: 3.3287e-04
# Epoch 14/50
# 381/381 [==============================] - 1s 3ms/step - loss: 9.8012e-04 - mean_absolute_error: 0.0230 - val_loss: 8.8978e-04 - val_mean_absolute_error: 0.0227 - lr: 3.0119e-04
# Epoch 15/50
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0010 - mean_absolute_error: 0.0232 - val_loss: 8.6271e-04 - val_mean_absolute_error: 0.0223 - lr: 2.7253e-04
# Epoch 16/50
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0010 - mean_absolute_error: 0.0234 - val_loss: 8.4068e-04 - val_mean_absolute_error: 0.0220 - lr: 2.4660e-04
# Epoch 17/50
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0010 - mean_absolute_error: 0.0237 - val_loss: 7.9817e-04 - val_mean_absolute_error: 0.0215 - lr: 2.2313e-04
# Epoch 18/50
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0239 - val_loss: 6.9485e-04 - val_mean_absolute_error: 0.0201 - lr: 2.0190e-04
# Epoch 19/50
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0239 - val_loss: 6.1612e-04 - val_mean_absolute_error: 0.0191 - lr: 1.8268e-04
# Epoch 20/50
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0237 - val_loss: 5.8868e-04 - val_mean_absolute_error: 0.0187 - lr: 1.6530e-04
# Epoch 21/50
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0235 - val_loss: 6.2680e-04 - val_mean_absolute_error: 0.0196 - lr: 1.4957e-04
# Epoch 22/50
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0010 - mean_absolute_error: 0.0232 - val_loss: 7.5834e-04 - val_mean_absolute_error: 0.0220 - lr: 1.3534e-04
# Epoch 23/50
# 381/381 [==============================] - 1s 3ms/step - loss: 9.7722e-04 - mean_absolute_error: 0.0228 - val_loss: 9.0274e-04 - val_mean_absolute_error: 0.0241 - lr: 1.2246e-04
# Epoch 24/50
# 381/381 [==============================] - 1s 4ms/step - loss: 9.4070e-04 - mean_absolute_error: 0.0223 - val_loss: 0.0010 - val_mean_absolute_error: 0.0259 - lr: 1.1080e-04
# Epoch 25/50
# 381/381 [==============================] - 1s 3ms/step - loss: 9.0134e-04 - mean_absolute_error: 0.0219 - val_loss: 0.0011 - val_mean_absolute_error: 0.0263 - lr: 1.0026e-04

# %%
plot_history(ss_cnn_history)

# %%
plot_predictions(ss_cnn, ss_sample_batch, 'single_step')

# %% [markdown]
# ### Combine CNN and LSTM

# %%
ss_cnn_lstm = Sequential([
    Conv1D(filters=32, kernel_size=(KERNEL_LENGTH,), activation='relu'),
    LSTM(32, return_sequences=True),
    Dense(1)
])

ss_cnn_lstm_history = train_model(ss_cnn_lstm, train_ds_ss, val_ds_ss, use_scheduler=True)
# Out:
# Epoch 1/50
# 381/381 [==============================] - 6s 7ms/step - loss: 0.0085 - mean_absolute_error: 0.0625 - val_loss: 0.0063 - val_mean_absolute_error: 0.0639
# Epoch 2/50
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0037 - mean_absolute_error: 0.0464 - val_loss: 0.0021 - val_mean_absolute_error: 0.0367
# Epoch 3/50
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0028 - mean_absolute_error: 0.0408 - val_loss: 0.0122 - val_mean_absolute_error: 0.0934
# Epoch 4/50
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0026 - mean_absolute_error: 0.0387 - val_loss: 0.0233 - val_mean_absolute_error: 0.1296
# Epoch 5/50
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0028 - mean_absolute_error: 0.0391 - val_loss: 0.0193 - val_mean_absolute_error: 0.1145
# Epoch 6/50
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0029 - mean_absolute_error: 0.0389 - val_loss: 0.0158 - val_mean_absolute_error: 0.1056
# Epoch 7/50
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0029 - mean_absolute_error: 0.0389 - val_loss: 0.0136 - val_mean_absolute_error: 0.0989
# Epoch 1/50
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0026 - mean_absolute_error: 0.0355 - val_loss: 0.0212 - val_mean_absolute_error: 0.1266 - lr: 0.0010
# Epoch 2/50
# 381/381 [==============================] - 2s 4ms/step - loss: 0.0026 - mean_absolute_error: 0.0347 - val_loss: 0.0164 - val_mean_absolute_error: 0.1099 - lr: 0.0010
# Epoch 3/50
# 381/381 [==============================] - 2s 4ms/step - loss: 0.0025 - mean_absolute_error: 0.0336 - val_loss: 0.0241 - val_mean_absolute_error: 0.1348 - lr: 9.0484e-04
# Epoch 4/50
# 381/381 [==============================] - 2s 4ms/step - loss: 0.0025 - mean_absolute_error: 0.0337 - val_loss: 0.0149 - val_mean_absolute_error: 0.1036 - lr: 8.1873e-04
# Epoch 5/50
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0023 - mean_absolute_error: 0.0320 - val_loss: 0.0166 - val_mean_absolute_error: 0.1062 - lr: 7.4082e-04
# Epoch 6/50
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0021 - mean_absolute_error: 0.0307 - val_loss: 0.0123 - val_mean_absolute_error: 0.0897 - lr: 6.7032e-04
# Epoch 7/50
# 381/381 [==============================] - 2s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0294 - val_loss: 0.0080 - val_mean_absolute_error: 0.0719 - lr: 6.0653e-04
# Epoch 8/50
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0016 - mean_absolute_error: 0.0272 - val_loss: 0.0046 - val_mean_absolute_error: 0.0573 - lr: 5.4881e-04
# Epoch 9/50
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0015 - mean_absolute_error: 0.0263 - val_loss: 0.0049 - val_mean_absolute_error: 0.0597 - lr: 4.9659e-04
# Epoch 10/50
# 381/381 [==============================] - 2s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0243 - val_loss: 0.0047 - val_mean_absolute_error: 0.0560 - lr: 4.4933e-04
# Epoch 11/50
# 381/381 [==============================] - 2s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0241 - val_loss: 0.0054 - val_mean_absolute_error: 0.0604 - lr: 4.0657e-04
# Epoch 12/50
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0010 - mean_absolute_error: 0.0229 - val_loss: 0.0034 - val_mean_absolute_error: 0.0451 - lr: 3.6788e-04
# Epoch 13/50
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0232 - val_loss: 0.0032 - val_mean_absolute_error: 0.0445 - lr: 3.3287e-04
# Epoch 14/50
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0234 - val_loss: 0.0015 - val_mean_absolute_error: 0.0304 - lr: 3.0119e-04
# Epoch 15/50
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0243 - val_loss: 0.0011 - val_mean_absolute_error: 0.0265 - lr: 2.7253e-04
# Epoch 16/50
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0250 - val_loss: 7.9271e-04 - val_mean_absolute_error: 0.0227 - lr: 2.4660e-04
# Epoch 17/50
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0255 - val_loss: 7.7525e-04 - val_mean_absolute_error: 0.0221 - lr: 2.2313e-04
# Epoch 18/50
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0257 - val_loss: 8.0155e-04 - val_mean_absolute_error: 0.0222 - lr: 2.0190e-04
# Epoch 19/50
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0257 - val_loss: 8.0453e-04 - val_mean_absolute_error: 0.0222 - lr: 1.8268e-04
# Epoch 20/50
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0255 - val_loss: 8.1938e-04 - val_mean_absolute_error: 0.0224 - lr: 1.6530e-04
# Epoch 21/50
# 381/381 [==============================] - 2s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0250 - val_loss: 8.5977e-04 - val_mean_absolute_error: 0.0232 - lr: 1.4957e-04
# Epoch 22/50
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0243 - val_loss: 8.8739e-04 - val_mean_absolute_error: 0.0239 - lr: 1.3534e-04

# %%
plot_history(ss_cnn_lstm_history)

# %%
plot_predictions(ss_cnn_lstm, ss_sample_batch, 'single_step')

# %% [markdown]
# ### Evaluation

# %%
model_list = ['Linear', 'DNN', 'LSTM', 'CNN', 'CNN+LSTM']

ss_mae = [0.032, 0.046, 0.036]
ss_mae.append(ss_cnn.evaluate(test_ds_ss)[1])
ss_mae.append(ss_cnn_lstm.evaluate(test_ds_ss)[1])

plot_evaluation(model_list, ss_mae)
# Out:
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0090 - mean_absolute_error: 0.0806
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0068 - mean_absolute_error: 0.0673

# %% [markdown]
# ## Multi-step model

# %%
KERNEL_LENGTH = 6
OUTPUT_LENGTH = 24
INPUT_LENGTH = OUTPUT_LENGTH + KERNEL_LENGTH - 1

train_ds_ms = format_timeseries_data(train_df, INPUT_LENGTH, OUTPUT_LENGTH, ['OT'])
val_ds_ms = format_timeseries_data(val_df, INPUT_LENGTH, OUTPUT_LENGTH, ['OT'])
test_ds_ms = format_timeseries_data(test_df, INPUT_LENGTH, OUTPUT_LENGTH, ['OT'])

ms_sample_batch = next(iter(test_ds_ms))

# %%
ms_cnn = Sequential([
    Conv1D(32, kernel_size=(KERNEL_LENGTH,), activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)
])

ms_cnn_history = train_model(ms_cnn, train_ds_ms, val_ds_ms)
# Out:
# Epoch 1/50
# 380/380 [==============================] - 3s 4ms/step - loss: 0.0279 - mean_absolute_error: 0.0919 - val_loss: 0.0224 - val_mean_absolute_error: 0.1232
# Epoch 2/50
# 380/380 [==============================] - 2s 4ms/step - loss: 0.0058 - mean_absolute_error: 0.0590 - val_loss: 0.0080 - val_mean_absolute_error: 0.0688
# Epoch 3/50
# 380/380 [==============================] - 2s 4ms/step - loss: 0.0051 - mean_absolute_error: 0.0553 - val_loss: 0.0033 - val_mean_absolute_error: 0.0466
# Epoch 4/50
# 380/380 [==============================] - 1s 4ms/step - loss: 0.0052 - mean_absolute_error: 0.0552 - val_loss: 0.0041 - val_mean_absolute_error: 0.0514
# Epoch 5/50
# 380/380 [==============================] - 1s 4ms/step - loss: 0.0054 - mean_absolute_error: 0.0558 - val_loss: 0.0037 - val_mean_absolute_error: 0.0496
# Epoch 6/50
# 380/380 [==============================] - 2s 4ms/step - loss: 0.0054 - mean_absolute_error: 0.0557 - val_loss: 0.0042 - val_mean_absolute_error: 0.0532
# Epoch 7/50
# 380/380 [==============================] - 1s 4ms/step - loss: 0.0053 - mean_absolute_error: 0.0555 - val_loss: 0.0038 - val_mean_absolute_error: 0.0506
# Epoch 8/50
# 380/380 [==============================] - 2s 4ms/step - loss: 0.0050 - mean_absolute_error: 0.0545 - val_loss: 0.0038 - val_mean_absolute_error: 0.0508

# %%
plot_history(ms_cnn_history)
# plot_predictions(ms_cnn, ms_sample_batch, 'multi_step')

# %% [markdown]
# ### Combine CNN and LSTM

# %%
ms_cnn_lstm = Sequential([
    Conv1D(32, kernel_size=(KERNEL_LENGTH,), activation='relu'),
    LSTM(32, return_sequences=True),
    LSTM(16, return_sequences=True),
    Dense(1)
])

ms_cnn_lstm_history = train_model(ms_cnn_lstm, train_ds_ms, val_ds_ms, use_scheduler=True)
# Out:
# Epoch 1/50
# 380/380 [==============================] - 18s 30ms/step - loss: 0.0144 - mean_absolute_error: 0.0780 - val_loss: 0.0123 - val_mean_absolute_error: 0.0954
# Epoch 2/50
# 380/380 [==============================] - 9s 25ms/step - loss: 0.0092 - mean_absolute_error: 0.0673 - val_loss: 0.0166 - val_mean_absolute_error: 0.1160
# Epoch 3/50
# 380/380 [==============================] - 10s 25ms/step - loss: 0.0094 - mean_absolute_error: 0.0688 - val_loss: 0.0244 - val_mean_absolute_error: 0.1438
# Epoch 4/50
# 380/380 [==============================] - 10s 25ms/step - loss: 0.0091 - mean_absolute_error: 0.0687 - val_loss: 0.0466 - val_mean_absolute_error: 0.1963
# Epoch 5/50
# 380/380 [==============================] - 9s 25ms/step - loss: 0.0070 - mean_absolute_error: 0.0635 - val_loss: 0.0337 - val_mean_absolute_error: 0.1634
# Epoch 6/50
# 380/380 [==============================] - 9s 25ms/step - loss: 0.0059 - mean_absolute_error: 0.0589 - val_loss: 0.0100 - val_mean_absolute_error: 0.0809
# Epoch 7/50
# 380/380 [==============================] - 10s 26ms/step - loss: 0.0054 - mean_absolute_error: 0.0571 - val_loss: 0.0026 - val_mean_absolute_error: 0.0396
# Epoch 8/50
# 380/380 [==============================] - 10s 25ms/step - loss: 0.0060 - mean_absolute_error: 0.0609 - val_loss: 0.0030 - val_mean_absolute_error: 0.0423
# Epoch 9/50
# 380/380 [==============================] - 10s 25ms/step - loss: 0.0071 - mean_absolute_error: 0.0649 - val_loss: 0.0030 - val_mean_absolute_error: 0.0421
# Epoch 10/50
# 380/380 [==============================] - 10s 25ms/step - loss: 0.0083 - mean_absolute_error: 0.0679 - val_loss: 0.0039 - val_mean_absolute_error: 0.0513
# Epoch 11/50
# 380/380 [==============================] - 9s 25ms/step - loss: 0.0082 - mean_absolute_error: 0.0673 - val_loss: 0.0043 - val_mean_absolute_error: 0.0550
# Epoch 12/50
# 380/380 [==============================] - 10s 26ms/step - loss: 0.0075 - mean_absolute_error: 0.0653 - val_loss: 0.0052 - val_mean_absolute_error: 0.0604
# Epoch 1/50
# 380/380 [==============================] - 10s 26ms/step - loss: 0.0071 - mean_absolute_error: 0.0635 - val_loss: 0.0059 - val_mean_absolute_error: 0.0651 - lr: 0.0010
# Epoch 2/50
# 380/380 [==============================] - 10s 25ms/step - loss: 0.0061 - mean_absolute_error: 0.0602 - val_loss: 0.0038 - val_mean_absolute_error: 0.0505 - lr: 0.0010
# Epoch 3/50
# 380/380 [==============================] - 10s 26ms/step - loss: 0.0061 - mean_absolute_error: 0.0600 - val_loss: 0.0031 - val_mean_absolute_error: 0.0452 - lr: 9.0484e-04
# Epoch 4/50
# 380/380 [==============================] - 10s 25ms/step - loss: 0.0057 - mean_absolute_error: 0.0582 - val_loss: 0.0028 - val_mean_absolute_error: 0.0413 - lr: 8.1873e-04
# Epoch 5/50
# 380/380 [==============================] - 10s 26ms/step - loss: 0.0055 - mean_absolute_error: 0.0571 - val_loss: 0.0028 - val_mean_absolute_error: 0.0411 - lr: 7.4082e-04
# Epoch 6/50
# 380/380 [==============================] - 10s 26ms/step - loss: 0.0056 - mean_absolute_error: 0.0563 - val_loss: 0.0027 - val_mean_absolute_error: 0.0396 - lr: 6.7032e-04
# Epoch 7/50
# 380/380 [==============================] - 10s 25ms/step - loss: 0.0053 - mean_absolute_error: 0.0558 - val_loss: 0.0027 - val_mean_absolute_error: 0.0403 - lr: 6.0653e-04
# Epoch 8/50
# 380/380 [==============================] - 10s 26ms/step - loss: 0.0074 - mean_absolute_error: 0.0602 - val_loss: 0.0025 - val_mean_absolute_error: 0.0394 - lr: 5.4881e-04
# Epoch 9/50
# 380/380 [==============================] - 10s 26ms/step - loss: 0.0046 - mean_absolute_error: 0.0529 - val_loss: 0.0028 - val_mean_absolute_error: 0.0397 - lr: 4.9659e-04
# Epoch 10/50
# 380/380 [==============================] - 10s 26ms/step - loss: 0.0066 - mean_absolute_error: 0.0575 - val_loss: 0.0024 - val_mean_absolute_error: 0.0387 - lr: 4.4933e-04
# Epoch 11/50
# 380/380 [==============================] - 10s 26ms/step - loss: 0.0054 - mean_absolute_error: 0.0560 - val_loss: 0.0023 - val_mean_absolute_error: 0.0373 - lr: 4.0657e-04
# Epoch 12/50
# 380/380 [==============================] - 10s 26ms/step - loss: 0.0064 - mean_absolute_error: 0.0579 - val_loss: 0.0022 - val_mean_absolute_error: 0.0370 - lr: 3.6788e-04
# Epoch 13/50
# 380/380 [==============================] - 10s 25ms/step - loss: 0.0058 - mean_absolute_error: 0.0572 - val_loss: 0.0021 - val_mean_absolute_error: 0.0364 - lr: 3.3287e-04
# Epoch 14/50
# 380/380 [==============================] - 10s 26ms/step - loss: 0.0066 - mean_absolute_error: 0.0590 - val_loss: 0.0021 - val_mean_absolute_error: 0.0361 - lr: 3.0119e-04
# Epoch 15/50
# 380/380 [==============================] - 10s 25ms/step - loss: 0.0063 - mean_absolute_error: 0.0592 - val_loss: 0.0021 - val_mean_absolute_error: 0.0362 - lr: 2.7253e-04
# Epoch 16/50
# 380/380 [==============================] - 10s 26ms/step - loss: 0.0069 - mean_absolute_error: 0.0608 - val_loss: 0.0021 - val_mean_absolute_error: 0.0360 - lr: 2.4660e-04
# Epoch 17/50
# 380/380 [==============================] - 10s 26ms/step - loss: 0.0068 - mean_absolute_error: 0.0610 - val_loss: 0.0021 - val_mean_absolute_error: 0.0360 - lr: 2.2313e-04
# Epoch 18/50
# 380/380 [==============================] - 10s 25ms/step - loss: 0.0070 - mean_absolute_error: 0.0618 - val_loss: 0.0021 - val_mean_absolute_error: 0.0358 - lr: 2.0190e-04
# Epoch 19/50
# 380/380 [==============================] - 10s 25ms/step - loss: 0.0068 - mean_absolute_error: 0.0614 - val_loss: 0.0021 - val_mean_absolute_error: 0.0357 - lr: 1.8268e-04
# Epoch 20/50
# 380/380 [==============================] - 10s 25ms/step - loss: 0.0067 - mean_absolute_error: 0.0613 - val_loss: 0.0021 - val_mean_absolute_error: 0.0355 - lr: 1.6530e-04
# Epoch 21/50
# 380/380 [==============================] - 10s 26ms/step - loss: 0.0065 - mean_absolute_error: 0.0607 - val_loss: 0.0021 - val_mean_absolute_error: 0.0355 - lr: 1.4957e-04
# Epoch 22/50
# 380/380 [==============================] - 9s 25ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0021 - val_mean_absolute_error: 0.0358 - lr: 1.3534e-04
# Epoch 23/50
# 380/380 [==============================] - 10s 26ms/step - loss: 0.0060 - mean_absolute_error: 0.0586 - val_loss: 0.0023 - val_mean_absolute_error: 0.0367 - lr: 1.2246e-04
# Epoch 24/50
# 380/380 [==============================] - 10s 25ms/step - loss: 0.0057 - mean_absolute_error: 0.0574 - val_loss: 0.0025 - val_mean_absolute_error: 0.0382 - lr: 1.1080e-04
# Epoch 25/50
# 380/380 [==============================] - 10s 26ms/step - loss: 0.0054 - mean_absolute_error: 0.0563 - val_loss: 0.0027 - val_mean_absolute_error: 0.0402 - lr: 1.0026e-04

# %%
plot_history(ms_cnn_lstm_history)
# plot_predictions(ms_cnn_lstm, ms_sample_batch, 'multi_step')

# %% [markdown]
# ### Evaluation

# %%
ms_mae = [0.123, 0.154, 0.174]
ms_mae.append(ms_cnn.evaluate(test_ds_ms)[1])
ms_mae.append(ms_cnn_lstm.evaluate(test_ds_ms)[1])

plot_evaluation(model_list, ms_mae)
# Out:
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0430 - mean_absolute_error: 0.1623
# 53/53 [==============================] - 1s 9ms/step - loss: 0.0396 - mean_absolute_error: 0.1591

# %% [markdown]
# ## Multi-output

# %%
KERNEL_LENGTH = 6
OUTPUT_LENGTH = 1
INPUT_LENGTH = OUTPUT_LENGTH + KERNEL_LENGTH - 1

train_ds_mo = format_timeseries_data(train_df, INPUT_LENGTH, OUTPUT_LENGTH, ['OT', 'MULL'])
val_ds_mo = format_timeseries_data(val_df, INPUT_LENGTH, OUTPUT_LENGTH, ['OT', 'MULL'])
test_ds_mo = format_timeseries_data(test_df, INPUT_LENGTH, OUTPUT_LENGTH, ['OT', 'MULL'])

mo_sample_batch = next(iter(test_ds_mo))

# %%
mo_cnn = Sequential([
    Conv1D(filters=32, kernel_size=(KERNEL_LENGTH,), activation='relu'),
    Dense(units=32, activation='relu'),
    Dense(units=2)
])

mo_cnn_history = train_model(mo_cnn, train_ds_mo, val_ds_mo)
# Out:
# Epoch 1/50
# 381/381 [==============================] - 3s 4ms/step - loss: 0.0108 - mean_absolute_error: 0.0713 - val_loss: 0.0605 - val_mean_absolute_error: 0.1870
# Epoch 2/50
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0050 - mean_absolute_error: 0.0532 - val_loss: 0.0299 - val_mean_absolute_error: 0.1341
# Epoch 3/50
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0047 - mean_absolute_error: 0.0510 - val_loss: 0.0128 - val_mean_absolute_error: 0.0899
# Epoch 4/50
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0036 - mean_absolute_error: 0.0452 - val_loss: 0.0112 - val_mean_absolute_error: 0.0830
# Epoch 5/50
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0033 - mean_absolute_error: 0.0436 - val_loss: 0.0037 - val_mean_absolute_error: 0.0485
# Epoch 6/50
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0034 - mean_absolute_error: 0.0442 - val_loss: 0.0030 - val_mean_absolute_error: 0.0432
# Epoch 7/50
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0034 - mean_absolute_error: 0.0436 - val_loss: 0.0036 - val_mean_absolute_error: 0.0488
# Epoch 8/50
# 381/381 [==============================] - 2s 4ms/step - loss: 0.0033 - mean_absolute_error: 0.0422 - val_loss: 0.0051 - val_mean_absolute_error: 0.0585
# Epoch 9/50
# 381/381 [==============================] - 2s 4ms/step - loss: 0.0031 - mean_absolute_error: 0.0417 - val_loss: 0.0064 - val_mean_absolute_error: 0.0639
# Epoch 10/50
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0032 - mean_absolute_error: 0.0417 - val_loss: 0.0063 - val_mean_absolute_error: 0.0646
# Epoch 11/50
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0031 - mean_absolute_error: 0.0405 - val_loss: 0.0053 - val_mean_absolute_error: 0.0600

# %%
plot_history(mo_cnn_history)
# plot_predictions(mo_cnn, mo_sample_batch, 'multi_output')

# %% [markdown]
# ### Combine CNN and LSTM

# %%
mo_cnn_lstm = Sequential([
    Conv1D(filters=32, kernel_size=(KERNEL_LENGTH,), activation='relu'),
    LSTM(units=32, return_sequences=True),
    LSTM(units=16, return_sequences=True),
    Dense(units=2)
])

mo_cnn_lstm_history = train_model(mo_cnn_lstm, train_ds_mo, val_ds_mo, use_scheduler=True)
# Out:
# Epoch 1/50
# 381/381 [==============================] - 10s 10ms/step - loss: 0.0273 - mean_absolute_error: 0.0971 - val_loss: 0.0093 - val_mean_absolute_error: 0.0786
# Epoch 2/50
# 381/381 [==============================] - 3s 7ms/step - loss: 0.0096 - mean_absolute_error: 0.0718 - val_loss: 0.0131 - val_mean_absolute_error: 0.0942
# Epoch 3/50
# 381/381 [==============================] - 3s 7ms/step - loss: 0.0087 - mean_absolute_error: 0.0685 - val_loss: 0.0204 - val_mean_absolute_error: 0.1134
# Epoch 4/50
# 381/381 [==============================] - 2s 7ms/step - loss: 0.0068 - mean_absolute_error: 0.0623 - val_loss: 0.0230 - val_mean_absolute_error: 0.1143
# Epoch 5/50
# 381/381 [==============================] - 3s 7ms/step - loss: 0.0057 - mean_absolute_error: 0.0575 - val_loss: 0.0160 - val_mean_absolute_error: 0.0936
# Epoch 6/50
# 381/381 [==============================] - 2s 6ms/step - loss: 0.0052 - mean_absolute_error: 0.0547 - val_loss: 0.0094 - val_mean_absolute_error: 0.0745
# Epoch 1/50
# 381/381 [==============================] - 3s 7ms/step - loss: 0.0051 - mean_absolute_error: 0.0545 - val_loss: 0.0050 - val_mean_absolute_error: 0.0551 - lr: 0.0010
# Epoch 2/50
# 381/381 [==============================] - 3s 7ms/step - loss: 0.0051 - mean_absolute_error: 0.0548 - val_loss: 0.0039 - val_mean_absolute_error: 0.0491 - lr: 0.0010
# Epoch 3/50
# 381/381 [==============================] - 2s 6ms/step - loss: 0.0052 - mean_absolute_error: 0.0547 - val_loss: 0.0039 - val_mean_absolute_error: 0.0499 - lr: 9.0484e-04
# Epoch 4/50
# 381/381 [==============================] - 3s 7ms/step - loss: 0.0046 - mean_absolute_error: 0.0513 - val_loss: 0.0039 - val_mean_absolute_error: 0.0498 - lr: 8.1873e-04
# Epoch 5/50
# 381/381 [==============================] - 2s 6ms/step - loss: 0.0038 - mean_absolute_error: 0.0462 - val_loss: 0.0035 - val_mean_absolute_error: 0.0462 - lr: 7.4082e-04
# Epoch 6/50
# 381/381 [==============================] - 3s 7ms/step - loss: 0.0033 - mean_absolute_error: 0.0426 - val_loss: 0.0030 - val_mean_absolute_error: 0.0422 - lr: 6.7032e-04
# Epoch 7/50
# 381/381 [==============================] - 2s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0407 - val_loss: 0.0030 - val_mean_absolute_error: 0.0414 - lr: 6.0653e-04
# Epoch 8/50
# 381/381 [==============================] - 2s 6ms/step - loss: 0.0028 - mean_absolute_error: 0.0389 - val_loss: 0.0033 - val_mean_absolute_error: 0.0440 - lr: 5.4881e-04
# Epoch 9/50
# 381/381 [==============================] - 3s 7ms/step - loss: 0.0025 - mean_absolute_error: 0.0372 - val_loss: 0.0037 - val_mean_absolute_error: 0.0470 - lr: 4.9659e-04
# Epoch 10/50
# 381/381 [==============================] - 3s 7ms/step - loss: 0.0023 - mean_absolute_error: 0.0357 - val_loss: 0.0038 - val_mean_absolute_error: 0.0470 - lr: 4.4933e-04
# Epoch 11/50
# 381/381 [==============================] - 2s 6ms/step - loss: 0.0022 - mean_absolute_error: 0.0344 - val_loss: 0.0036 - val_mean_absolute_error: 0.0457 - lr: 4.0657e-04
# Epoch 12/50
# 381/381 [==============================] - 2s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0333 - val_loss: 0.0036 - val_mean_absolute_error: 0.0452 - lr: 3.6788e-04

# %%
plot_history(mo_cnn_lstm_history)
# plot_predictions(mo_cnn_lstm, mo_sample_batch, 'multi_output')

# %% [markdown]
# ### Evaluation

# %%
mo_mae = [0.05, 0.069, 0.093]

mo_mae.append(mo_cnn.evaluate(test_ds_mo)[1])
mo_mae.append(mo_cnn_lstm.evaluate(test_ds_mo)[1])

plot_evaluation(model_list, mo_mae)
# Out:
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0167 - mean_absolute_error: 0.1056
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0141 - mean_absolute_error: 0.0941
